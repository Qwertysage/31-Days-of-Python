# %% [markdown]
# <a href="https://colab.research.google.com/github/Qwertysage/31-Days-of-Python/blob/main/JSON%20Day%2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import JSON
# It's builtin Python installations for any versions in the past few years.

# %%
import json

# %% [markdown]
# ## Convert JSON to Dict

# %%
a = json.loads('{"name":"John"}')
print(a)
type(a)
# Out:
# {'name': 'John'}
# dict

# %%
print(a["name"])
# Out:
# John

# %% [markdown]
# ## Convert Dict to JSON

# %%
a = json.dumps(a)
print(a)
type(a)
# Out:
# {"name": "John"}
# str

# %% [markdown]
# ## Beware
# Some people don't follow standards. Make sure you check or trust there are no duplicate keys.

# %%
a = json.loads('{"name":"John", "name":"Johns"}')
print(a)
# Out:
# {'name': 'Johns'}

# %% [markdown]
# ## Example, formatting, and comparison
#
# Making and converting a dictionary that contains the basic data types.

# %%
myDict = {
    "dictPersons" : [
        {
            "age" : 52,
            "gpa" : 3.4,
            "name" : "Mike",
            "hasGraduated" : True,
            "isEnrolled" : False,
            "tuitionBalance" : None,
        },
        {
            "age" : 19,
            "gpa" : 2.9,
            "name" : "Larry",
            "hasGraduated" : True,
            "isEnrolled" : True,
            "tuitionBalance" : 135000.55,
        },
        {
            "age" : 23,
            "gpa" : 3.7,
            "name" : "Ashley",
            "hasGraduated" : False,
            "isEnrolled" : True,
            "tuitionBalance" : 0.0,
        }
    ]
}

# %%
print(json.dumps(myDict))
# Out:
# {"dictPersons": [{"age": 52, "gpa": 3.4, "name": "Mike", "hasGraduated": true, "isEnrolled": false, "tuitionBalance": null}, {"age": 19, "gpa": 2.9, "name": "Larry", "hasGraduated": true, "isEnrolled": true, "tuitionBalance": 135000.55}, {"age": 23, "gpa": 3.7, "name": "Ashley", "hasGraduated": false, "isEnrolled": true, "tuitionBalance": 0.0}]}

# %% [markdown]
# ### Sorting and Readability

# %%
print(json.dumps(myDict, indent=3, sort_keys=True))
# Out:
# {
#    "dictPersons": [
#       {
#          "age": 52,
#          "gpa": 3.4,
#          "hasGraduated": true,
#          "isEnrolled": false,
#          "name": "Mike",
#          "tuitionBalance": null
#       },
#       {
#          "age": 19,
#          "gpa": 2.9,
#          "hasGraduated": true,
#          "isEnrolled": true,
#          "name": "Larry",
#          "tuitionBalance": 135000.55
#       },
#       {
#          "age": 23,
#          "gpa": 3.7,
#          "hasGraduated": false,
#          "isEnrolled": true,
#          "name": "Ashley",
#          "tuitionBalance": 0.0
#       }
#    ]
# }

# %% [markdown]
# ### Comparing JSON to Dictionary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# json.load() and json.dump() are options too.  They require an extra parameter as file object.

# %% [markdown]
# Real world would look something like below <br />
#
# Read in json: <br />
# with open("Filename.txt") as file: <br />
#   json.load(myDict, file) <br />
#
# Write dict into a json file: <br />
# with open("Filename.txt", 'r+') as file:<br />
#   json.dump(myDict, file) <br />
